# %%
# Load the dataset
df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/default/datsetvolume/ci_cd_logs.csv")

# Preview
display(df)

# %%
#Handle missing or incorrect logs.
from pyspark.sql.functions import col, trim, when

df_clean = df.withColumn("status", trim(col("status")))

df_clean.createOrReplaceTempView("ci_cd_logs")
